# %% [markdown]
# <a href="https://www.kaggle.com/code/kgxiao/pytorch-cnn?scriptVersionId=106211900" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import os
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import datetime

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.optim as optim

# %%
#load data
train_set = pd.read_csv('../input/digit-recognizer/train.csv')
test_set = pd.read_csv('../input/digit-recognizer/test.csv')

# %%
#scale
train_set[:][1:] = train_set[:][1:].values / 255.0
test_set[:][:]= test_set[:][:].values / 255.0

# %%
valid_size = 0.1
data_nums = len(train_set)
indices = list(range(data_nums))

np.random.shuffle(indices)
splits = int(np.floor(valid_size * data_nums))
train_ind, valid_ind = indices[splits:], indices[:splits]

train_s = SubsetRandomSampler(train_ind)
valid_s = SubsetRandomSampler(valid_ind)

# %%
#dataloader
class Datamnist(Dataset):
    
    def __init__(self, data, transforms=None, labels=True):
        
        self.data = data
        self.transforms = transforms
        self.labels = labels
        
    def __len__(self):
        
        return len(self.data)
    
    def __getitem__(self, index):
        
        dataset = self.data.iloc[index]
        if self.labels:
            x = dataset[1:].values.astype(np.uint8).reshape((28, 28))
            y = dataset[0]
        
        else:
            x = dataset[0:].values.astype(np.uint8).reshape((28, 28))
            y = 0
        
        if self.transforms is not None:
            
            x = self.transforms(x)
        
        return x, y

# %%
transforms_dic = {'train':
               transforms.Compose([transforms.ToPILImage(),
               transforms.RandomAffine(8, translate=(0, 0.1), scale=(0.8, 1.2)),
               transforms.ToTensor()]),
               'valid':
               transforms.Compose([transforms.ToTensor()]),
               'test':
               transforms.Compose([transforms.ToTensor()])
              }

train = Datamnist(train_set, transforms_dic['train'])
valid = Datamnist(train_set, transforms_dic['valid'])
test = Datamnist(test_set, transforms_dic['test'], labels=False)

train_loader = DataLoader(train, batch_size=128, sampler=train_s)
valid_loader = DataLoader(valid, sampler=valid_s)
test_loader = DataLoader(test)

# %%
class Convmodel(nn.Module):
    
    def __init__(self, outputs=10, chanles=10):
        super().__init__()
        self.outputs = outputs
        self.chanles = chanles
        
        self.dr = nn.Dropout2d(p=0.3, inplace=True)
        self.cov1 = nn.Conv2d(1, self.chanles*1, 3) #outs:  26*26
        self.bn1 = nn.BatchNorm2d(self.chanles*1)
        self.cov2 = nn.Conv2d(self.chanles*1, self.chanles*2, 3) #outs: 24*24
        self.bn2 = nn.BatchNorm2d(self.chanles*2)
        
        self.cov3 = nn.Conv2d(self.chanles*2, self.chanles*3, 5) #outs: 20*20
        self.bn3 = nn.BatchNorm2d(self.chanles*3)
        self.cov4 = nn.Conv2d(self.chanles*3, self.chanles*4, 5) #outs: 16*16
        self.bn4 = nn.BatchNorm2d(self.chanles*4)
        
        self.p1 = nn.MaxPool2d(4) #outs:4*4
        self.l1 = nn.Linear(self.chanles*4*4*4,128)
        self.l2 = nn.Linear(128,64)
        self.bn5 = nn.BatchNorm1d(64)
        self.l3 = nn.Linear(64,10)
        
    def forward(self, x):
        out = self.bn1(F.relu(self.cov1(x))) #26 * 26
        out = self.bn2(F.relu(self.cov2(out))) #24 * 24
        out = self.dr(self.bn3(F.relu(self.cov3(out)))) #20*20
        out = self.dr(self.p1(self.bn4(F.relu(self.cov4(out))))) #4*4*chanles*4
        out = out.view(-1,self.chanles*4*4*4)
        out = self.dr(self.bn5(self.l2(self.l1(out))))
        out = self.l3(out)
        
        return out

# %%
def write_info(file, info:str, statue=True):
    
    if statue:
        print(info)

    file.write(info)
    file.write('\n')
    return None

# %%
class Runmodel:
    
    def __init__(self, traindata, validdata, epochs=20, lr=0.01):
        
        self.epochs = epochs
        self.traindata = traindata
        self.validdata = validdata
        self.lr = lr
        self.model = self.model_init()
        self.loss = self.model_loss()
        self.optim = torch.optim.Adam(self.model.parameters(), lr=self.lr)
        
        if not os.path.exists('pytorch_model.txt'):
            f=open('pytorch_model.txt',"w")
            f.write(f"{'*'*10}Model train and valid infomation.{'*'*10}\n")
            f.close()
        
    def model_init(self):
        
        return Convmodel()
    
        
    def train(self):
        #train
        self.model.train()
        n_total_correct = 0.0
        n_total_samples = 0.0
        
        #valid metrics for all epochs
        n_total_valid_acc = 0.0
        n_total_valid_sam = 0.0
        files = open('pytorch_model.txt', mode='a+')
        write_info(files, f"epochs: {self.epochs}, learning_rate: {self.lr}")
        
        time_sta = datetime.datetime.now()
        
        for epoch in range(self.epochs):
            
            n_samples = 0.0
            n_correct = 0.0
            
            for i, (data, label) in enumerate(self.traindata):
                outputs = self.model(data)
                loss = self.loss(outputs, label)
                self.optim.zero_grad()
                loss.backward()
                self.optim.step()
                
                _, predicted = outputs.max(1)
                n_correct += (predicted == label).sum().item()
                n_samples += label.shape[0]
                
                n_total_correct += (predicted == label).sum().item()
                n_total_samples += label.shape[0]
                                
                if (i+1) % 50 == 0:
                    i_time = datetime.datetime.now()
                    info = f'time:[{i_time-time_sta}], train epoch:[{epoch+1} / {self.epochs}], sample proportion:[{100*(n_samples/(len(self.traindata.dataset))):.2f}%], current Loss:[{loss.item():.6f}]'
                    write_info(files, info)
            
            epoch_time = datetime.datetime.now()
            write_info(files, f'epoch time:[{epoch_time-time_sta}], train sets acc: [{100*(n_correct/n_samples):.2f}%]')
            
            #valid acc
            n_valid_correct, n_valid_sam = self.valid(files)   #epoch correct for valid
            n_total_valid_acc += n_valid_correct
            n_total_valid_sam += n_valid_sam
        
        all_time = datetime.datetime.now()
        write_info(files, f'====All time:[{all_time - time_sta}]====')
        write_info(files, f'Arain total Acc: [{100*(n_total_correct/n_total_samples):.2f}%]')
        write_info(files, f'Valid total Acc: [{100*(n_total_valid_acc/n_total_valid_sam):.2f}%]')
        
        files.close()
        
    def valid(self,files):
        #valida data
        with torch.no_grad():
            self.model.eval()
            n_total_correct = 0.0
            n_total_samples = 0.0
            
            for i, (data, label) in enumerate(self.validdata):
                
                outputs = self.model(data)
                _, predicted = outputs.max(1)
                
                n_total_correct += (predicted == label).sum().item()
                n_total_samples += label.shape[0]
            
            write_info(files, f'>>>>valid sets acc:[{100*(n_total_correct/n_total_samples):.2f}%]')
            
            return n_total_correct, n_total_samples
        
    
        
    def predict(self, testdata):
        #predict for test
        with torch.no_grad():
            self.model.eval()
            test_pred = torch.LongTensor()
            for data, _ in testdata:
                
                outs = self.model(data)
                pred = outs.max(1, keepdim=True)[1]
                test_pred = torch.cat((test_pred, pred), dim=0)
                
            out_df = pd.DataFrame(np.c_[np.arange(1, len(testdata)+1)[:,None], test_pred.numpy()], 
                      columns=['ImageId', 'Label'])
            
        return out_df.to_csv('submission.csv', index=False)
    
    def model_loss(self):
        #loss func
        criterion = nn.CrossEntropyLoss()
        return criterion

# %%
Trainmodel = Runmodel(train_loader, valid_loader)
Trainmodel.train()
# Out:
# epochs: 20, learning_rate: 0.01
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1320: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# time:[0:00:09.731232], train epoch:[1 / 20], sample proportion:[15.24%], current Loss:[0.925504]
# time:[0:00:19.430580], train epoch:[1 / 20], sample proportion:[30.48%], current Loss:[0.896117]
# time:[0:00:28.893119], train epoch:[1 / 20], sample proportion:[45.71%], current Loss:[0.755088]
# time:[0:00:38.403462], train epoch:[1 / 20], sample proportion:[60.95%], current Loss:[0.880313]
# time:[0:00:48.208780], train epoch:[1 / 20], sample proportion:[76.19%], current Loss:[0.812696]
# epoch time:[0:00:56.908752], train sets acc: [64.79%]
# >>>>valid sets acc:[96.40%]
# time:[0:01:12.668774], train epoch:[2 / 20], sample proportion:[15.24%], current Loss:[0.148873]
# time:[0:01:21.823225], train epoch:[2 / 20], sample proportion:[30.48%], current Loss:[0.143837]
# time:[0:01:30.920479], train epoch:[2 / 20], sample proportion:[45.71%], current Loss:[0.067621]
# time:[0:01:40.063547], train epoch:[2 / 20], sample proportion:[60.95%], current Loss:[0.122642]
# time:[0:01:49.326372], train epoch:[2 / 20], sample proportion:[76.19%], current Loss:[0.127718]
# epoch time:[0:01:57.570165], train sets acc: [95.84%]
# >>>>valid sets acc:[98.81%]
# time:[0:02:13.459472], train epoch:[3 / 20], sample proportion:[15.24%], current Loss:[0.118581]
# time:[0:02:22.738753], train epoch:[3 / 20], sample proportion:[30.48%], current Loss:[0.077364]
# time:[0:02:31.861750], train epoch:[3 / 20], sample proportion:[45.71%], current Loss:[0.016345]
# time:[0:02:40.860938], train epoch:[3 / 20], sample proportion:[60.95%], current Loss:[0.084336]
# time:[0:02:50.195939], train epoch:[3 / 20], sample proportion:[76.19%], current Loss:[0.052742]
# epoch time:[0:02:58.410968], train sets acc: [97.09%]
# >>>>valid sets acc:[98.24%]
# time:[0:03:13.981959], train epoch:[4 / 20], sample proportion:[15.24%], current Loss:[0.144530]
# time:[0:03:23.293554], train epoch:[4 / 20], sample proportion:[30.48%], current Loss:[0.185995]
# time:[0:03:32.407048], train epoch:[4 / 20], sample proportion:[45.71%], current Loss:[0.066027]
# time:[0:03:41.431069], train epoch:[4 / 20], sample proportion:[60.95%], current Loss:[0.022633]
# time:[0:03:50.626853], train epoch:[4 / 20], sample proportion:[76.19%], current Loss:[0.109627]
# epoch time:[0:03:58.868556], train sets acc: [97.52%]
# >>>>valid sets acc:[98.81%]
# time:[0:04:14.394369], train epoch:[5 / 20], sample proportion:[15.24%], current Loss:[0.075773]
# time:[0:04:23.783348], train epoch:[5 / 20], sample proportion:[30.48%], current Loss:[0.029181]
# time:[0:04:32.896526], train epoch:[5 / 20], sample proportion:[45.71%], current Loss:[0.138735]
# time:[0:04:41.960535], train epoch:[5 / 20], sample proportion:[60.95%], current Loss:[0.016002]
# time:[0:04:51.220407], train epoch:[5 / 20], sample proportion:[76.19%], current Loss:[0.036338]
# epoch time:[0:04:59.426782], train sets acc: [97.85%]
# >>>>valid sets acc:[98.83%]
# time:[0:05:15.148950], train epoch:[6 / 20], sample proportion:[15.24%], current Loss:[0.073571]
# time:[0:05:24.350549], train epoch:[6 / 20], sample proportion:[30.48%], current Loss:[0.070463]
# time:[0:05:33.394028], train epoch:[6 / 20], sample proportion:[45.71%], current Loss:[0.037784]
# time:[0:05:42.464038], train epoch:[6 / 20], sample proportion:[60.95%], current Loss:[0.136982]
# time:[0:05:51.787351], train epoch:[6 / 20], sample proportion:[76.19%], current Loss:[0.159760]
# epoch time:[0:06:00.111575], train sets acc: [97.78%]
# >>>>valid sets acc:[98.79%]
# time:[0:06:15.637352], train epoch:[7 / 20], sample proportion:[15.24%], current Loss:[0.063660]
# time:[0:06:24.862324], train epoch:[7 / 20], sample proportion:[30.48%], current Loss:[0.081824]
# time:[0:06:33.898123], train epoch:[7 / 20], sample proportion:[45.71%], current Loss:[0.100840]
# time:[0:06:42.888940], train epoch:[7 / 20], sample proportion:[60.95%], current Loss:[0.028289]
# time:[0:06:51.928383], train epoch:[7 / 20], sample proportion:[76.19%], current Loss:[0.037066]
# epoch time:[0:07:00.288792], train sets acc: [98.11%]
# >>>>valid sets acc:[98.48%]
# time:[0:07:15.959650], train epoch:[8 / 20], sample proportion:[15.24%], current Loss:[0.119401]
# time:[0:07:25.010525], train epoch:[8 / 20], sample proportion:[30.48%], current Loss:[0.152862]
# time:[0:07:34.228537], train epoch:[8 / 20], sample proportion:[45.71%], current Loss:[0.071857]
# time:[0:07:43.349677], train epoch:[8 / 20], sample proportion:[60.95%], current Loss:[0.098336]
# time:[0:07:52.370698], train epoch:[8 / 20], sample proportion:[76.19%], current Loss:[0.051291]
# epoch time:[0:08:00.779772], train sets acc: [98.09%]
# >>>>valid sets acc:[99.05%]
# time:[0:08:16.343539], train epoch:[9 / 20], sample proportion:[15.24%], current Loss:[0.041906]
# time:[0:08:25.373329], train epoch:[9 / 20], sample proportion:[30.48%], current Loss:[0.078548]
# time:[0:08:34.550255], train epoch:[9 / 20], sample proportion:[45.71%], current Loss:[0.049076]
# time:[0:08:43.526557], train epoch:[9 / 20], sample proportion:[60.95%], current Loss:[0.035010]
# time:[0:08:52.551845], train epoch:[9 / 20], sample proportion:[76.19%], current Loss:[0.057423]
# epoch time:[0:09:00.916021], train sets acc: [98.39%]
# >>>>valid sets acc:[99.10%]
# time:[0:09:16.770872], train epoch:[10 / 20], sample proportion:[15.24%], current Loss:[0.010243]
# time:[0:09:27.943016], train epoch:[10 / 20], sample proportion:[30.48%], current Loss:[0.122602]
# time:[0:09:37.139124], train epoch:[10 / 20], sample proportion:[45.71%], current Loss:[0.007577]
# time:[0:09:46.209537], train epoch:[10 / 20], sample proportion:[60.95%], current Loss:[0.124522]
# time:[0:09:55.268564], train epoch:[10 / 20], sample proportion:[76.19%], current Loss:[0.025441]
# epoch time:[0:10:03.712920], train sets acc: [98.42%]
# >>>>valid sets acc:[98.57%]
# time:[0:10:19.819323], train epoch:[11 / 20], sample proportion:[15.24%], current Loss:[0.064099]
# time:[0:10:29.104926], train epoch:[11 / 20], sample proportion:[30.48%], current Loss:[0.133695]
# time:[0:10:38.491161], train epoch:[11 / 20], sample proportion:[45.71%], current Loss:[0.065295]
# time:[0:10:47.757528], train epoch:[11 / 20], sample proportion:[60.95%], current Loss:[0.036682]
# time:[0:10:56.848610], train epoch:[11 / 20], sample proportion:[76.19%], current Loss:[0.043810]
# epoch time:[0:11:05.324622], train sets acc: [98.30%]
# >>>>valid sets acc:[98.90%]
# time:[0:11:20.842872], train epoch:[12 / 20], sample proportion:[15.24%], current Loss:[0.166937]
# time:[0:11:29.934084], train epoch:[12 / 20], sample proportion:[30.48%], current Loss:[0.107688]
# time:[0:11:39.157088], train epoch:[12 / 20], sample proportion:[45.71%], current Loss:[0.007681]
# time:[0:11:48.230292], train epoch:[12 / 20], sample proportion:[60.95%], current Loss:[0.015486]
# time:[0:11:57.340132], train epoch:[12 / 20], sample proportion:[76.19%], current Loss:[0.017156]
# epoch time:[0:12:05.823954], train sets acc: [98.45%]
# >>>>valid sets acc:[99.12%]
# time:[0:12:21.669872], train epoch:[13 / 20], sample proportion:[15.24%], current Loss:[0.103171]
# time:[0:12:30.797088], train epoch:[13 / 20], sample proportion:[30.48%], current Loss:[0.087432]
# time:[0:12:40.113367], train epoch:[13 / 20], sample proportion:[45.71%], current Loss:[0.115492]
# time:[0:12:49.221613], train epoch:[13 / 20], sample proportion:[60.95%], current Loss:[0.051784]
# time:[0:12:58.403142], train epoch:[13 / 20], sample proportion:[76.19%], current Loss:[0.050188]
# epoch time:[0:13:06.896334], train sets acc: [98.42%]
# >>>>valid sets acc:[99.10%]
# time:[0:13:22.445408], train epoch:[14 / 20], sample proportion:[15.24%], current Loss:[0.043405]
# time:[0:13:31.593519], train epoch:[14 / 20], sample proportion:[30.48%], current Loss:[0.013131]
# time:[0:13:40.929602], train epoch:[14 / 20], sample proportion:[45.71%], current Loss:[0.070790]
# time:[0:13:50.050193], train epoch:[14 / 20], sample proportion:[60.95%], current Loss:[0.031356]
# time:[0:13:59.189085], train epoch:[14 / 20], sample proportion:[76.19%], current Loss:[0.014018]
# epoch time:[0:14:07.518412], train sets acc: [98.43%]
# >>>>valid sets acc:[99.26%]
# time:[0:14:23.076273], train epoch:[15 / 20], sample proportion:[15.24%], current Loss:[0.068288]
# time:[0:14:32.501500], train epoch:[15 / 20], sample proportion:[30.48%], current Loss:[0.021560]
# time:[0:14:42.427756], train epoch:[15 / 20], sample proportion:[45.71%], current Loss:[0.020769]
# time:[0:14:51.788995], train epoch:[15 / 20], sample proportion:[60.95%], current Loss:[0.063874]
# time:[0:15:01.020680], train epoch:[15 / 20], sample proportion:[76.19%], current Loss:[0.045385]
# epoch time:[0:15:09.366158], train sets acc: [98.57%]
# >>>>valid sets acc:[99.45%]
# time:[0:15:25.238456], train epoch:[16 / 20], sample proportion:[15.24%], current Loss:[0.020110]
# time:[0:15:34.582656], train epoch:[16 / 20], sample proportion:[30.48%], current Loss:[0.026504]
# time:[0:15:44.090575], train epoch:[16 / 20], sample proportion:[45.71%], current Loss:[0.097515]
# time:[0:15:53.278176], train epoch:[16 / 20], sample proportion:[60.95%], current Loss:[0.012699]
# time:[0:16:02.497773], train epoch:[16 / 20], sample proportion:[76.19%], current Loss:[0.055702]
# epoch time:[0:16:10.944427], train sets acc: [98.64%]
# >>>>valid sets acc:[99.33%]
# time:[0:16:26.619347], train epoch:[17 / 20], sample proportion:[15.24%], current Loss:[0.016561]
# time:[0:16:35.661030], train epoch:[17 / 20], sample proportion:[30.48%], current Loss:[0.006963]
# time:[0:16:44.944325], train epoch:[17 / 20], sample proportion:[45.71%], current Loss:[0.035224]
# time:[0:16:54.072271], train epoch:[17 / 20], sample proportion:[60.95%], current Loss:[0.079578]
# time:[0:17:03.167112], train epoch:[17 / 20], sample proportion:[76.19%], current Loss:[0.038397]
# epoch time:[0:17:11.458276], train sets acc: [98.56%]
# >>>>valid sets acc:[99.10%]
# time:[0:17:27.484913], train epoch:[18 / 20], sample proportion:[15.24%], current Loss:[0.048026]
# time:[0:17:36.633646], train epoch:[18 / 20], sample proportion:[30.48%], current Loss:[0.017334]
# time:[0:17:45.832439], train epoch:[18 / 20], sample proportion:[45.71%], current Loss:[0.004354]
# time:[0:17:55.159123], train epoch:[18 / 20], sample proportion:[60.95%], current Loss:[0.018983]
# time:[0:18:04.267108], train epoch:[18 / 20], sample proportion:[76.19%], current Loss:[0.050720]
# epoch time:[0:18:12.629979], train sets acc: [98.59%]
# >>>>valid sets acc:[99.21%]
# time:[0:18:28.213624], train epoch:[19 / 20], sample proportion:[15.24%], current Loss:[0.067682]
# time:[0:18:37.289447], train epoch:[19 / 20], sample proportion:[30.48%], current Loss:[0.019043]
# time:[0:18:46.405445], train epoch:[19 / 20], sample proportion:[45.71%], current Loss:[0.032332]
# time:[0:18:55.640957], train epoch:[19 / 20], sample proportion:[60.95%], current Loss:[0.060464]
# time:[0:19:04.780910], train epoch:[19 / 20], sample proportion:[76.19%], current Loss:[0.014123]
# epoch time:[0:19:13.080492], train sets acc: [98.63%]
# >>>>valid sets acc:[99.19%]
# time:[0:19:28.998977], train epoch:[20 / 20], sample proportion:[15.24%], current Loss:[0.008444]
# time:[0:19:38.114397], train epoch:[20 / 20], sample proportion:[30.48%], current Loss:[0.027829]
# time:[0:19:47.247171], train epoch:[20 / 20], sample proportion:[45.71%], current Loss:[0.011086]
# time:[0:19:56.549644], train epoch:[20 / 20], sample proportion:[60.95%], current Loss:[0.011404]
# time:[0:20:05.691841], train epoch:[20 / 20], sample proportion:[76.19%], current Loss:[0.053055]
# epoch time:[0:20:14.009646], train sets acc: [98.74%]
# >>>>valid sets acc:[99.26%]
# ====All time:[0:20:20.858407]====
# Arain total Acc: [96.46%]
# Valid total Acc: [98.85%]

# %%
Trainmodel.predict(test_loader)
print('ok')
# Out:
# ok
